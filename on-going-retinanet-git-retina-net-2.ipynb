# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        (os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install pycocotools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 2.4 MB/s eta 0:00:0000:0100:01m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone https://github.com/G-venkatesh1/retina_net_2.git
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 372 bytes | 372.00 KiB/s, done.
# From https://github.com/G-venkatesh1/retina_net_2
#    1197064..bfb2b6e  master     -> origin/master
# Updating 1197064..bfb2b6e
# Fast-forward
#  retinanet/model.py | 8 ++++----
#  1 file changed, 4 insertions(+), 4 deletions(-)

# %%
cd retina_net_2
# Out:
# /kaggle/working/retina_net_2

# %%
# !python coco_validation.py --coco_path '/kaggle/input/coco-2017-dataset/coco2017' --model_path '/kaggle/input/retina_net/pytorch/model/1/coco_resnet_50_map_0_335_state_dict.pt'

# %%
# !pip install onnx
# !pip install onnxruntime

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), 380 bytes | 380.00 KiB/s, done.
# From https://github.com/G-venkatesh1/retina_net_2
#    b41b214..190e85d  master     -> origin/master
# Updating b41b214..190e85d
# Fast-forward
#  sample.py | 46 +++++++++++++++++++++++-----------------------
#  1 file changed, 23 insertions(+), 23 deletions(-)

# %%
# !python sample.py
# Out:
# /kaggle/working/retina_net_2/retinanet/anchors.py:24: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   image_shape = np.array(image_shape)
# /kaggle/working/retina_net_2/retinanet/anchors.py:38: TracerWarning: torch.from_numpy results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   return torch.from_numpy(all_anchors.astype(np.float32)).cuda()
# ...

# %%
import onnxruntime
ort_session = onnxruntime.InferenceSession('/kaggle/working/retina_net_2/ret_new.onnx')

# %%
ort_inputs = {'input.1': None}

# %%
ort_inputs['input.1'] = inputs.cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ort_inputs['input.1'] = inputs.cpu().numpy()
#
# NameError: name 'inputs' is not defined

# %%
ort_outs = ort_session.run(None, ort_inputs)
            scores, labels, boxes = ort_outs[0], ort_outs[1], ort_outs[2]
